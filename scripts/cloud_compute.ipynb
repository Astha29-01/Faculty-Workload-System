# %%
import subprocess

def run_pipeline_on_cloud():
    print("Simulating EC2 instance execution...\n")
    
    # Run your pipeline
    subprocess.run(["python", "scripts/pipeline_runner.py"])
    
    print("\nPipeline executed on cloud compute")

if __name__ == "__main__":
    run_pipeline_on_cloud()
# Out:
# Simulating EC2 instance execution...
#
#
# Pipeline executed on cloud compute
