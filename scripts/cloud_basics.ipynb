# %%
def cloud_comparison():
    print("\nCloud Platform Comparison:\n")
    
    print("AWS  -> S3 | EC2 | Redshift")
    print("GCP  -> Cloud Storage | Compute Engine | BigQuery")
    print("Azure-> Blob Storage | Virtual Machines | Synapse")

if __name__ == "__main__":
    cloud_comparison()
# Out:
# Cloud Platform Comparison:
#
# AWS  -> S3 | EC2 | Redshift
# GCP  -> Cloud Storage | Compute Engine | BigQuery
# Azure-> Blob Storage | Virtual Machines | Synapse
